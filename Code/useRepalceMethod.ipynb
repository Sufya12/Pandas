# %%
#Import The Libriary
import pandas as pd
import numpy as np

# %%
#Read The File
df = pd.read_csv('data12.csv')

# %%
#Print The Data Frame
df
# Out:
#         day  temperature  windspeed       event
# 0  1/1/2017           32           6       Rain
# 1  1/2/2017       -99999           7      Sunny
# 2  1/3/2017           28      -99999       Snow
# 3  1/4/2017       -99999           7   No Event
# 4  1/5/2017           32      -99999      Rain
# 5  1/6/2017           31           2      Sunny
# 6  1/6/2017           34           5  Not Event

# %%
#Repalce The Data Frame Values other Values 
new_df = df.replace(-99999,np.NaN)

# %%
#Print Data Frame
new_df
# Out:
#         day  temperature  windspeed       event
# 0  1/1/2017         32.0         6.0       Rain
# 1  1/2/2017          NaN         7.0      Sunny
# 2  1/3/2017         28.0         NaN       Snow
# 3  1/4/2017          NaN         7.0   No Event
# 4  1/5/2017         32.0         NaN      Rain
# 5  1/6/2017         31.0         2.0      Sunny
# 6  1/6/2017         34.0         5.0  Not Event

# %%
#Read The File
df1 = pd.read_csv('data12.csv')

# %%
#Print The Data Frame
df1
# Out:
#         day  temperature  windspeed       event
# 0  1/1/2017           32           6       Rain
# 1  1/2/2017       -99999           7      Sunny
# 2  1/3/2017           28      -99999       Snow
# 3  1/4/2017       -99999           7   No Event
# 4  1/5/2017           32      -88888      Rain
# 5  1/6/2017           31           2      Sunny
# 6  1/6/2017           34           5  Not Event

# %%
#Repalce The Data Frame Values other Values 
new_df1 = df.replace([-99999,-88888],np.NaN)

# %%
#Print Data Frame
new_df1
# Out:
#         day  temperature  windspeed       event
# 0  1/1/2017         32.0         6.0       Rain
# 1  1/2/2017          NaN         7.0      Sunny
# 2  1/3/2017         28.0         NaN       Snow
# 3  1/4/2017          NaN         7.0   No Event
# 4  1/5/2017         32.0         NaN      Rain
# 5  1/6/2017         31.0         2.0      Sunny
# 6  1/6/2017         34.0         5.0  Not Event

# %%
#Replace The Value
new_df2 = new_df1.replace('[A-Za-z]','',regex = True)

# %%
#Print The Data Frame
new_df2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0         6.0
# 1  1/2/2017          NaN         7.0
# 2  1/3/2017         28.0         NaN
# 3  1/4/2017          NaN         7.0
# 4  1/5/2017         32.0         NaN
# 5  1/6/2017         31.0         2.0
# 6  1/6/2017         34.0         5.0

# %%
#Create The Data Frame
df3 = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})

# %%
#The Data Frame Are Print
df3
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
